# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
Files = ['2024/Metodos20242.xlsx']
df = pd.read_excel(Files[0])

# %%
df.keys()
# Out:
# Index(['Username', 'Last Name', 'First Name', 'Derivacion', 'Interpolacion',
#        'Parcial 1', 'Integracion', 'Algebra Lineal', 'Parcial 2',
#        'MinimosCuadrados', 'Modelos', 'Parcial 3', 'Complementaria'],
#       dtype='object')

# %%
dfparciales = df[['Parcial 1','Parcial 2','Parcial 3']]
dftalleres = df[['Derivacion','Interpolacion','Integracion','Algebra Lineal','MinimosCuadrados','Modelos']]

# %%
df = df.assign( Talleres = dftalleres.mean(axis=1) )
df = df.assign( Parciales = dfparciales.mean(axis=1))

# %%
df[['Talleres','Parciales']]
# Out:
#     Talleres  Parciales
# 0   4.753333   4.793333
# 1   4.850000   4.453333
# 2   4.345000   3.666667
# 3   4.505000   4.503333
# 4   4.768333   4.833333
# 5   2.683333   3.133333
# 6   3.705000   3.303333
# 7   3.293333   3.753333
# 8   4.525000   4.760000
# 9   3.548333   1.166667
# 10  3.685000   4.173333
# 11  4.810000   4.750000
# 12  3.900000   3.836667
# 13  4.290000   3.970000
# 14  4.555000   4.203333
# 15  4.798333   4.886667
# 16  4.768333   4.833333
# 17  4.810000   4.750000
# 18  4.850000   4.386667
# 19  3.940000   3.303333
# 20  3.900000   3.836667
# 21  3.255000   4.336667
# 22  4.215000   4.186667
# 23  4.555000   4.103333
# 24  4.215000   4.186667
# 25  3.685000   4.043333
# 26  4.841667   4.826667
# 27  4.841667   4.826667
# 28  4.798333   4.886667
# 29  3.293333   3.753333
# 30  4.505000   4.503333
# 31  3.685000   4.043333
# 32  2.693333   4.560000
# 33  3.685000   4.206667
# 34  4.410000   3.970000
# 35  4.345000   3.666667
# 36  4.753333   4.793333

# %%
# ponderación acordada
df = df.assign( NotaFinal = np.round(0.75*(df.Parciales*0.5+df.Talleres*0.5) + 0.25*df.Complementaria,2) ) 
#df

# %%
dffinal = df[['Last Name','First Name', 'NotaFinal']]
dffinal
#dffinal.sort_values(by='NotaFinal')
# Out:
#               Last Name         First Name  NotaFinal
# 0       Angarita Rincon    Pedro Alejandro       4.60
# 1               Arnache             Samuel       4.73
# 2                Bareño      Juan Fernando       3.80
# 3        Castillo Manso     Emily Gabriela       4.51
# 4               Cavanzo              Pablo       4.85
# 5         Diaz Quintero            Nicolas       3.14
# 6        Diaz Salamanca    Cristian Andres       3.65
# 7   Duque Duque Blandon              David       3.02
# 8               Feldman       Jacobo Isaac       4.55
# 9         Galeano Pinto       Darcy Lorena       2.51
# 10          Gomez Ayala   Nicolas Mauricio       4.09
# 11          Gomez Cañon     Maria Fernanda       4.83
# 12          Gomez Ochoa        Juan Camilo       4.15
# 13   Gutierrez Perdigon         Juan Diego       4.04
# 14  Hernandez Hernandez            Juliana       3.77
# 15             Martinez         Juan Pablo       4.88
# 16          Morillo Roa     Antonio Rafael       4.85
# 17        Moya Gonzalez            Mariana       4.60
# 18          Osorio Mora  Alejandra Del Mar       4.45
# 19       Payares Ustate         Juan David       3.97
# 20       Perea Pescador          Ana Maria       3.88
# 21    Phillips Carvajal      Eduardo David       3.74
# 22         Quevedo Leal        Karen Sofia       4.32
# 23      Ramirez Alvarez       Maria Camila       4.09
# 24       Ramirez Suarez     Gabriel Steven       4.34
# 25      Rangel Peñafiel       Dynna Emelic       3.69
# 26        Rocha Barajas    Andrea Carolina       4.88
# 27            Rodriguez           Gabriela       4.88
# 28            Rodriguez           Santiago       4.60
# 29       Rodriguez Peña   Kennet Alejandro       3.65
# 30      Rodriguez Velez     Juan Sebastian       4.57
# 31        Romero Moreno      Samuel Felipe       3.25
# 32        Sanchez Gomez       Juan Esteban       3.35
# 33      Santos Walteros   Jaider Sebastian       3.89
# 34        Simahan Reyes       Joseph David       4.39
# 35            Tocasuche      Laura Vanessa       4.04
# 36          Uribe Uribe              Simon       4.83

# %%
dffinal.to_excel('Metodos1.xlsx',index=False,float_format="%.2f")

# %%
percentiles = np.percentile(dffinal.NotaFinal,[0,25,50,75,100])



fig = plt.figure(figsize=(5,5))
ax = fig.add_subplot(111)

ax.set_xticklabels(['Métodos computacionales 1'], rotation=1, fontsize=15)

ax.boxplot(dffinal.NotaFinal)
ax.set_ylabel('Grades', fontsize=15)

for i in range(len(percentiles)):
    ax.text(1+0.1,percentiles[i],np.round(percentiles[i],2),color='r')
# Out:
# /tmp/ipykernel_6071/2066457746.py:8: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(['Métodos computacionales 1'], rotation=1, fontsize=15)
