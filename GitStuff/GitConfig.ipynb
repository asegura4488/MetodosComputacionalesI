# %%
# Configuracion git
# !git config --global user.email "asegura4488@gmail.com"
# !git config --global user.name "asegura4488"

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/ColabNotebooks/Cursos/
# Out:
# /content/drive/MyDrive/ColabNotebooks/Cursos

# %%
# !ls
# Out:
# GitConfig.ipynb  GitUpdate.ipynb  MetodosComputacionalesI

# %%
#!rm -rf MetodosComputacionalesI/

# %%
#!git clone https://<your-username>:<your-token>@github.com/<your-username>/<your-repository>.git

# %%
cd MetodosComputacionalesI/
# Out:
# [Errno 2] No such file or directory: 'MetodosComputacionalesI/'
# /content/drive/MyDrive/ColabNotebooks/Cursos/MetodosComputacionalesI

# %%
# !ls
# Out:
# ProyectoML  Semana1  Semana3  Semana5  Semana7	Semana9
# README.md   Semana2  Semana4  Semana6  Semana8
